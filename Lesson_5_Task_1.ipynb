# %%
# %matplotlib inline
import numpy as np

# %%
#Метод Монте-Карло:
for i in range(0, 150):
    a = input()
    x = np.random.uniform(0, 37)
    if x<=18 and x!= 0:
        print('red')
        if x == 0:
            print('zero')
    else:
        print('black')
# Out:
# black
#
# red
#
# red
#
# red
#
# red
#
# black
#
# red
#
# red
#
# red
#
# black
#
# black
#
# red
#
# black
#
# black
#
# red
#
# red
#
# black
#
# black
#
# red
#
# red
#
# black
#
# black
#
# black
#
# black
#
# red
#
# black
#
# red
#
# black
#
# red
#
# black
#
# black
#
# black
#
# red
#
# black
#
# red
#
# black
#
# red
#
# red
#
# red
#
# black
#
# black
#
# black
#
# black
#
# black
#
# red
#
# black
#
# red
#
# black
#
# black
#
# black
#
# black
#
# black
#
# black
#
# black
#
# black
#
# red
#
# red
#
# black
#
# black
#
# red
#
# black
#
# black
#
# black
#
# red
#
# red
#
# red
#
# red
#
# black
#
# red
#
# black
#
# red
#
# red
#
# black
#
# red
#
# black
#
# black
#
# black
#
# black
#
# black
#
# black
#
# black
#
# black
#
# black
#
# red
#
# red
#
# black
#
# red
#
# black
#
# red
#
# red
#
# black
#
# red
#
# red
#
# red
#
# black
#
# black
#
# black
#
# red
#
# red
#
# red
#
# black
#
# black
#
# red
#
# black
#
# red
#
# red
#
# red
#
# red
#
# red
#
# red
#
# ...
